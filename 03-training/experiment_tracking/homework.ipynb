# %%
from mlflow.tracking import MlflowClient

MLFLOW_TRACKING_URI = "sqlite:///mlflow.db"

client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)
# Out:
# 2026/04/19 16:46:47 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/04/19 16:46:47 INFO mlflow.store.db.utils: Updating database tables

# %%
client.list_experiments()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 client.list_experiments()
#
# AttributeError: 'MlflowClient' object has no attribute 'list_experiments'

# %%
client.create_experiment(name="prashant_experiment")
